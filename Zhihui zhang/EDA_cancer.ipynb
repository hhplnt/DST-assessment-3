# %%
import pandas as pd

# %%
df=pd.read_csv('77_cancer_proteomes_CPTAC_itraq.csv')

# %%
df.head()
# Out:
#   RefSeq_accession_number gene_symbol           gene_name  AO-A12D.01TCGA  \
# 0               NP_958782        PLEC   plectin isoform 1        1.096131
# 1               NP_958785         NaN  plectin isoform 1g        1.111370
# 2               NP_958786        PLEC  plectin isoform 1a        1.111370
# 3               NP_000436         NaN  plectin isoform 1c        1.107561
# 4               NP_958781         NaN  plectin isoform 1e        1.115180
#
#    C8-A131.01TCGA  AO-A12B.01TCGA  BH-A18Q.02TCGA  C8-A130.02TCGA  \
# 0        2.609943       -0.659828        0.195341       -0.494060
# 1        2.650422       -0.648742        0.215413       -0.503899
# 2        2.650422       -0.654285        0.215413       -0.500619
# 3        2.646374       -0.632113        0.205377       -0.510459
# 4        2.646374       -0.640428        0.215413       -0.503899
#
#    C8-A138.03TCGA  E2-A154.03TCGA  ...  AO-A12B.34TCGA  A2-A0SW.35TCGA  \
# ...

# %%
df
# Out:
#       RefSeq_accession_number gene_symbol  \
# 0                   NP_958782        PLEC
# 2                   NP_958786        PLEC
# 5                   NP_958780        PLEC
# 6                   NP_958783        PLEC
# 9                   NP_001611       AHNAK
# ...                       ...         ...
# 12323            NP_001094348     C8ORF73
# 12385               NP_443073       TSSK3
# 12432            NP_001004456       OR1M1
# 12463               NP_997625       ARL4A
# 12464               NP_003270       TNNC2
#
#                                                gene_name  AO-A12D.01TCGA  \
# 0                                      plectin isoform 1        1.096131
# 2                                     plectin isoform 1a        1.111370
# 5                                     plectin isoform 1f        1.107561
# 6                                     plectin isoform 1d        1.111370
# 9      neuroblast differentiation-associated protein ...        0.482754
# ...

# %%
df.isna().sum()
# Out:
# RefSeq_accession_number       0
# gene_symbol                1780
# gene_name                     0
# AO-A12D.01TCGA             1219
# C8-A131.01TCGA             1218
#                            ...
# BH-A0C7.36TCGA             2860
# A2-A0SX.36TCGA             2856
# 263d3f-I.CPTAC             1641
# blcdb9-I.CPTAC             1668
# c4155b-C.CPTAC             1640
# Length: 86, dtype: int64

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.isna().sum()
# Out:
# RefSeq_accession_number    0
# gene_symbol                0
# gene_name                  0
# AO-A12D.01TCGA             0
# C8-A131.01TCGA             0
#                           ..
# BH-A0C7.36TCGA             0
# A2-A0SX.36TCGA             0
# 263d3f-I.CPTAC             0
# blcdb9-I.CPTAC             0
# c4155b-C.CPTAC             0
# Length: 86, dtype: int64

# %%
df.head()
# Out:
#   RefSeq_accession_number gene_symbol  \
# 0               NP_958782        PLEC
# 2               NP_958786        PLEC
# 5               NP_958780        PLEC
# 6               NP_958783        PLEC
# 9               NP_001611       AHNAK
#
#                                            gene_name  AO-A12D.01TCGA  \
# 0                                  plectin isoform 1        1.096131
# 2                                 plectin isoform 1a        1.111370
# 5                                 plectin isoform 1f        1.107561
# 6                                 plectin isoform 1d        1.111370
# 9  neuroblast differentiation-associated protein ...        0.482754
#
#    C8-A131.01TCGA  AO-A12B.01TCGA  BH-A18Q.02TCGA  C8-A130.02TCGA  \
# 0        2.609943       -0.659828        0.195341       -0.494060
# 2        2.650422       -0.654285        0.215413       -0.500619
# 5        2.646374       -0.654285        0.215413       -0.503899
# ...
